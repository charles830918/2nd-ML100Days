# %% [markdown]
# Day_001_HW

# %%
# 作業1
請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要

我選擇 Suicide Rates Overview 1985 to 2016 這個資料集，希望能探究人們在怎麼樣的社會經濟狀況下，自殺率會提高或下降。如果能找到與自殺有關的原因，也許就能藉此降低人們自殺的可能性。


2. 資料從何而來

這個資料集由 United Nations Development Program、World Bank、Szamil 及 World Health Organization 所提供的資料組成，並由 Rusty 負責維護。資料取得的方式可能有網路爬蟲、結構化表單、資料庫 API。


3. 蒐集而來的資料型態為何

這個資料集為 csv 檔，資料型態為結構化資料： Integer、Floot、Text。


4. 這組資料想解決的問題如何評估

我們想問的問題是，在怎麼樣的社會經濟狀況下，自殺率會提高/下降，所以可以用迴歸 (Mean Squared Error, MSE) 作為評估。
# Out:
#   File "<ipython-input-17-556555b8754a>", line 4
#     1. 你選的這組資料為何重要
#                  ^
# SyntaxError: invalid syntax

# %%
# 作業2

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：


1. 核心問題為何

身為一個自由載客的車隊，我想知道在不同時刻下各地區的搭車需求，因此問題為在不同時刻下，各地區搭車需求是否有關？


2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

先統整過去載客的 GPS 紀錄


3. 蒐集而來的資料型態為何

資料型態可能是結構化的資料：Timestamp 和 Floot。


4. 你要回答的問題，其如何評估 

想問的問題是，在不同時刻下，各地區搭車需求是否有關，所以可以用迴歸 (Mean Squared Error, MSE) 作為評估。

# %%
# 作業3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y-yp)**2)/len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 201.953
# The Mean absolute error is 11.525
